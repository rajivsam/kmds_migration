# %%
import pandas as pd
import numpy as np

from dd_cleaner.notebook_utils import (
    init_notebook_session, 
    get_raw_data, 
    get_cleaned_data, 
    get_tagged_entities,
    get_attributes_by_tag
)

# Initialize the session pointing to the parent directory (tests/)
coord, artifacts_df = init_notebook_session("..")

# Display the artifacts table
artifacts_df

# 1. Initialize session and load the 'Clean Baseline'
# Point to the directory containing the 'data/' folder
coord, _ = init_notebook_session("..")
df = get_cleaned_data(coord)

print(f"Loaded Baseline: {df.shape[0]} rows, {df.shape[1]} columns")
# Out:
# ✅ Notebook session initialized for workspace: /home/rajiv/programming/kmds_migration/itsm_analysis
# Available Artifacts:
#                      Artifact Name                                 File Name  \
# 0                         Raw Data                   itsm_group_analysis.csv
# 1                     Cleaned Data             itsm_group_analysis_clean.csv
# 2                User Cleaned Data      itsm_group_analysis_user_cleaned.csv
# 3             Tagged Entities (DD)  itsm_group_analysis_analysis_results.csv
# 4  Cleaning Recommendations Report               cleaning_recommendations.md
# 5                 Profiling Report   itsm_group_analysis_profiling_report.md
# 6                   Handshake File               parser_cleaner_handshake.md
# 7                  Quarantine File        itsm_group_analysis_quarantine.csv
# 8               Metadata Authority    itsm_group_analysis_metadata_table.csv
#
#                                             Location  Exists
# 0                       data/itsm_group_analysis.csv    True
# 1      data/dd_cleaner/itsm_group_analysis_clean.csv    True
# 2  data/dd_cleaner/itsm_group_analysis_user_clean...   False
# 3  documents/dd_analysis_results/itsm_group_analy...    True
# 4   documents/dd_cleaner/cleaning_recommendations.md    True
# 5  documents/dd_cleaner/itsm_group_analysis_profi...    True
# 6   documents/dd_cleaner/parser_cleaner_handshake.md    True
# 7  data/quarantine/itsm_group_analysis_quarantine...   False
# 8  data/dd_cleaner/itsm_group_analysis_metadata_t...   False
# ✅ Notebook session initialized for workspace: /home/rajiv/programming/kmds_migration/itsm_analysis
# Available Artifacts:
#                      Artifact Name                                 File Name  \
# 0                         Raw Data                   itsm_group_analysis.csv
# 1                     Cleaned Data             itsm_group_analysis_clean.csv
# 2                User Cleaned Data      itsm_group_analysis_user_cleaned.csv
# 3             Tagged Entities (DD)  itsm_group_analysis_analysis_results.csv
# 4  Cleaning Recommendations Report               cleaning_recommendations.md
# 5                 Profiling Report   itsm_group_analysis_profiling_report.md
# 6                   Handshake File               parser_cleaner_handshake.md
# 7                  Quarantine File        itsm_group_analysis_quarantine.csv
# 8               Metadata Authority    itsm_group_analysis_metadata_table.csv
#
#                                             Location  Exists
# 0                       data/itsm_group_analysis.csv    True
# 1      data/dd_cleaner/itsm_group_analysis_clean.csv    True
# 2  data/dd_cleaner/itsm_group_analysis_user_clean...   False
# 3  documents/dd_analysis_results/itsm_group_analy...    True
# 4   documents/dd_cleaner/cleaning_recommendations.md    True
# 5  documents/dd_cleaner/itsm_group_analysis_profi...    True
# 6   documents/dd_cleaner/parser_cleaner_handshake.md    True
# 7  data/quarantine/itsm_group_analysis_quarantine...   False
# 8  data/dd_cleaner/itsm_group_analysis_metadata_t...   False
# Loaded Baseline: 141712 rows, 5 columns

# %%
df.head()
# Out:
#        number            opened_at assignment_group          resolved_at  \
# 0  INC0000045  2016-02-29 01:16:00         Group 56  2016-02-29 11:29:00
# 1  INC0000045  2016-02-29 01:16:00         Group 56  2016-02-29 11:29:00
# 2  INC0000045  2016-02-29 01:16:00         Group 56  2016-02-29 11:29:00
# 3  INC0000045  2016-02-29 01:16:00         Group 56  2016-02-29 11:29:00
# 4  INC0000047  2016-02-29 04:40:00         Group 70  2016-03-01 09:52:00
#
#              closed_at
# 0  2016-03-05 12:00:00
# 1  2016-03-05 12:00:00
# 2  2016-03-05 12:00:00
# 3  2016-03-05 12:00:00
# 4  2016-03-06 10:00:00
